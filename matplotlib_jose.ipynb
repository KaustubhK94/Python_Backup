# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)

# %%
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#FUNCTIONAL METHODS

# %%
plt.plot(x,y)

# %%
# plt.show()
# only to use this when not using jupyter

# %%
plt.plot(x,y,"r-")

# %%
plt.plot(x,y)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
# Parameters are no. of rows, no. of columns 
# and the plot number you're refering to
plt.plot(x,y,"r")
plt.subplot(1,2,2)
plt.plot(y,x,"b")

# %%
plt.subplot(1,2,1)  # Parameters are no. of rows, no. of columns  # and the plot number you're refering to
plt.plot(x,y,"r")
plt.plot(1,2,2)
plt.plot(y,x,"b")

# %%
#  OOP approach
fig = plt.figure()

# %%
axes = fig.add_axes([0.1,0.1,0.8,0.8])
# axes = fig.add_axes([1,1,1,0.5])
# params are left bottom width and height ranging 0 to 1

# %%
axes.plot(x,y)
fig

# %%
axes.set_xlabel("X label")
axes.set_ylabel("Y Label")
axes.set_title("Set Title")
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
#  arguments are left bottom width height
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y)
axes2.plot(y,x)
axes1.set_title("Larger Plot",{"color":"r"})
axes2.set_title("Smaller Plot")
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig = plt.figure()
axe = fig.add_axes([0.1,0.1,0.8,0.8])
axeii = fig.add_axes([0.19,0.5,0.4,0.3])
# arguments are left bottom width height
axe.plot(x,y)
axeii.plot(y,x)
axe.set_title("Larger Plot")
axeii.set_title("Smaller Plot")
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig = plt.figure()
axe = fig.add_axes([0.1,0.1,0.8,0.8])
fig.show()
# Out:
# C:\Users\KAUSTU~1\AppData\Local\Temp/ipykernel_3352/3683087239.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig,axes = plt.subplots()
axes.plot(x,y)
# axe = fig.add_axes([0.1,0.1,0.8,0.8])
# in object oriented method we create new cell or black canvas

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# %%
fig,axes = plt.subplots(nrows=2,ncols=3)
# plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows=2,ncols=3)
plt.tight_layout()

# %%
axes
# array of matplolib axis
# Out:
# array([<AxesSubplot:title={'center':'Normal scale'}>,
#        <AxesSubplot:title={'center':'Logarithmic scale (y)'}>],
#       dtype=object)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
for current_ax in axes:
  current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title("First Plot",{"color":"r"})
axes[1].plot(y,x)
axes[1].set_title("Second Plot",{"color":"b"})
# Out:
# Text(0.5, 1.0, 'Second Plot')

# %%
# Figure size and DPI

# %%
fig = plt.figure(figsize=(8,2))  #inches
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=2,ncols=1,figsize=(6,3))
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()

# %%
fig.savefig("mat_plot_lib.pdf",dpi=200)

# %%
pwd
# Out:
# 'C:\\Users\\kaustubh kapare'

# %%
fig = plt.figure(figsize=(4,3))  #inches
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_title("Title",{"color":"r"})
ax.set_ylabel("Y")
ax.set_xlabel("X")
# Out:
# Text(0.5, 0, 'X')

# %%
fig = plt.figure(figsize=(6,5))  #inches
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,"r")
ax.plot(y,x,"b")

# %%
fig = plt.figure(figsize=(6,5))  #inches
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,"r",label="X Squared")
ax.set_xlabel("Value")
ax.plot(x,x**3,"b",label="X Cubed")
ax.set_ylabel("Exponents")
ax.legend(loc=0)
# else can use tuple((0.1,0.1))

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color="red",linewidth=1,alpha = 1,linestyle="-",marker = "o",markersize = 20,markerfacecolor = "yellow",
       markeredgewidth = 3,markeredgecolor="green") 
ax.set_xlabel("X label",color = "red")
ax.set_ylabel("Y label",color = "black")
# alpha is for transparency
# you can use lw instead linewidth
# linestyles are "--",":","-.","steps","-"
#  youy can use Ls instead of linestyle
#  markers are "+","1",
# marker size
# Out:
# Text(0, 0.5, 'Y label')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color="#FF8C00") #RGB hex code

# %%
x
# len(x)
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color="red",linewidth=2,alpha = 1,linestyle="--")
ax.set_xlim([0,1])
ax.set_ylim([0,2])

# ax.set_xlabel("X label",color = "red")
# ax.set_ylabel("Y label",color = "black")
# Out:
# (0.0, 2.0)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,4))
      
axes[0].plot(x, x**2, x, np.exp(x))
print(x)
print(x**2)
print(np.exp(x))
axes[0].set_title("Normal scale")

axes[1].plot(x, x**2, x, np.exp(x))
axes[1].set_yscale("log")
axes[1].set_title("Logarithmic scale (y)")
# Out:
# [1 2 3]
# [1 4 9]
# [ 2.71828183  7.3890561  20.08553692]
# Text(0.5, 1.0, 'Logarithmic scale (y)')

# %%
x = np.array([1,2,3])

# %%
y = np.exp(x)

# %%
y

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
plt.plot(x,y,)

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x,y,"maroon")
ax2.plot(x,y,"maroon")

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.4,0.4])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.4,0.4])
ax1.plot(x,z,"b")
ax1.set_xlabel("X",{"color":"r"})
ax1.set_ylabel("Z",{"color":"r"})
ax2.plot(x,y,"b")
ax2.set_xlabel("X",{"color":"r"})
ax2.set_xlim([20,22])
ax2.set_ylim([30,50])
ax2.set_title("zoom",{"color":"r"})
ax2.set_ylabel("Y",{"color":"r"})
# Out:
# Text(0, 0.5, 'Y')

# %%
fig,axes = plt.subplots(nrows=1,ncols =2)
axes[0].plot(x,y,"b",lw=3,linestyle="--")
axes[1].plot(x,z,"r",linewidth = 4)
plt.tight_layout()

# %%
import numpy as np

# %%
x  = np.arange(1,6)
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
y = np.exp(x)
y
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692,  54.59815003,
#        148.4131591 ])

# %%
plt.fill_between([2,2.02],[7.38,7.53],color="g" )
plt.plot(x,y)

# %%
# f(x) = x**2
# f'(x) = 2x

# %%
np.exp(2)
# Out:
# 7.38905609893065

# %%
np.exp(2.02)
# Out:
# 7.538324933661922
