# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cufflinks as cf
from plotly import __version__
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected= True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
import seaborn as sns
sns.set_style("whitegrid")

# %%
# start = datetime.datetime(2006,1,1)
# end = datetime.datetime(2016,1,1)
# BAC = data.DataReader("BAC","google",start,end)
df = pd.read_pickle("D:/Data Sciences/Py-DS-ML-Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/all_banks")

# %%
df
# Out:
# Bank Ticker    BAC                                      C                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
# Bank of America
bac = df["BAC"]
bac
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000
# ...           ...    ...    ...    ...       ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415
# 2015-12-28  17.22  17.23  16.98  17.13  41777497
# 2015-12-29  17.25  17.35  17.16  17.28  45670376
# 2015-12-30  17.20  17.24  17.04  17.05  35066378
# 2015-12-31  17.01  17.07  16.83  16.83  47152968
#
# [2517 rows x 5 columns]

# %%
# City Bank
c= df["C"]
c
# Out:
# Stock Info    Open    High     Low   Close    Volume
# Date
# 2006-01-03  490.00  493.80  481.10  492.90   1537660
# 2006-01-04  488.60  491.00  483.50  483.80   1871020
# 2006-01-05  484.40  487.80  484.00  486.20   1143160
# 2006-01-06  488.80  489.00  482.00  486.20   1370250
# 2006-01-09  486.00  487.40  483.00  483.90   1680740
# ...            ...     ...     ...     ...       ...
# 2015-12-24   52.48   52.97   52.45   52.71   4671254
# 2015-12-28   52.57   52.57   51.96   52.38   8761743
# 2015-12-29   52.76   53.22   52.74   52.98  10155134
# 2015-12-30   52.84   52.94   52.25   52.30   8763337
# 2015-12-31   52.07   52.39   51.75   51.75  11281771
#
# [2517 rows x 5 columns]

# %%
# goldman Sachs
gs = df["GS"]
gs
# Out:
# Stock Info    Open    High     Low   Close   Volume
# Date
# 2006-01-03  126.70  129.44  124.23  128.87  6188700
# 2006-01-04  127.35  128.91  126.38  127.09  4862000
# 2006-01-05  126.00  127.32  125.61  127.04  3717600
# 2006-01-06  127.29  129.25  127.29  128.84  4319600
# 2006-01-09  128.50  130.62  128.00  130.39  4723500
# ...            ...     ...     ...     ...      ...
# 2015-12-24  182.27  183.17  182.02  182.47  1107633
# 2015-12-28  181.77  181.93  179.84  181.62  1723330
# 2015-12-29  182.82  184.18  182.50  183.53  1848921
# 2015-12-30  183.28  183.53  181.84  182.01  1514347
# 2015-12-31  181.16  182.88  180.03  180.23  1773881
#
# [2517 rows x 5 columns]

# %%
# .JP Morgan
jpm = df["JPM"]
jpm
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  39.83  40.36  39.30  40.19  12839400
# 2006-01-04  39.78  40.14  39.42  39.62  13491800
# 2006-01-05  39.61  39.81  39.50  39.74   8109400
# 2006-01-06  39.92  40.24  39.55  40.02   7966900
# 2006-01-09  39.88  40.72  39.88  40.67  16575200
# ...           ...    ...    ...    ...       ...
# 2015-12-24  66.62  66.89  66.32  66.60   4468242
# 2015-12-28  66.29  66.45  65.71  66.38   6610609
# 2015-12-29  66.84  67.30  66.74  67.07   9820830
# 2015-12-30  67.04  67.05  66.45  66.59   7190650
# 2015-12-31  66.19  66.78  66.00  66.03  14654329
#
# [2517 rows x 5 columns]

# %%
# Morgan Stanley
ms = df["MS"]
ms
# Out:
# Stock Info   Open   High    Low  Close   Volume
# Date
# 2006-01-03  57.17  58.49  56.74  58.31  5377000
# 2006-01-04  58.70  59.28  58.35  58.35  7977800
# 2006-01-05  58.55  58.59  58.02  58.51  5778000
# 2006-01-06  58.77  58.85  58.05  58.57  6889800
# 2006-01-09  58.63  59.29  58.62  59.19  4144500
# ...           ...    ...    ...    ...      ...
# 2015-12-24  32.57  32.71  32.44  32.48  2798163
# 2015-12-28  32.36  32.36  31.95  32.17  5420280
# 2015-12-29  32.44  32.70  32.32  32.55  6388244
# 2015-12-30  32.50  32.64  32.20  32.23  5057162
# 2015-12-31  31.91  32.30  31.77  31.81  8154307
#
# [2517 rows x 5 columns]

# %%
# Wells Fargo 
wfc = df["WFC"]
wfc
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  31.60  31.98  31.20  31.90  11016400
# 2006-01-04  31.80  31.82  31.36  31.53  10871000
# 2006-01-05  31.50  31.56  31.31  31.50  10158000
# 2006-01-06  31.58  31.78  31.38  31.68   8403800
# 2006-01-09  31.68  31.82  31.56  31.68   5619600
# ...           ...    ...    ...    ...       ...
# 2015-12-24  54.97  55.09  54.71  54.82   4999417
# 2015-12-28  54.55  54.78  54.17  54.68   8288841
# 2015-12-29  55.11  55.35  54.99  55.29   7894876
# 2015-12-30  55.27  55.31  54.79  54.89   8016893
# 2015-12-31  54.51  54.95  54.22  54.36  10929767
#
# [2517 rows x 5 columns]

# %%
tickers = ["bac","c","gs","jpm","ms","wfc"]

# %%
bank_stock = pd.concat([bac,c,gs,jpm,ms,wfc],axis=1,keys=tickers)

# %%
bank_stock
# Out:
#               bac                                      c                  \
# Stock Info   Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04  47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05  46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06  46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09  46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...           ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28  17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29  17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30  17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31  17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
bank_stock.columns.names = ["Bank Ticker","Stock Info"]

# %%
bank_stock
# Out:
# Bank Ticker    bac                                      c                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
bank_stock.xs(key="Close",axis=1,level="Stock Info").max()
# Out:
# Bank Ticker
# bac     54.90
# c      564.10
# gs     247.92
# jpm     70.08
# ms      89.30
# wfc     58.52
# dtype: float64

# %%
for tick in tickers:
    print(tick, bank_stock[tick]["Close"].max())
# bank_stock[("bac","c")]["Close"].max()
# Out:
# bac 54.9
# c 564.1
# gs 247.92
# jpm 70.08
# ms 89.3
# wfc 58.52

# %%
bank_stock.xs(key="Close",axis=1,level="Stock Info")
# Out:
# Bank Ticker    bac       c      gs    jpm     ms    wfc
# Date
# 2006-01-03   47.08  492.90  128.87  40.19  58.31  31.90
# 2006-01-04   46.58  483.80  127.09  39.62  58.35  31.53
# 2006-01-05   46.64  486.20  127.04  39.74  58.51  31.50
# 2006-01-06   46.57  486.20  128.84  40.02  58.57  31.68
# 2006-01-09   46.60  483.90  130.39  40.67  59.19  31.68
# ...            ...     ...     ...    ...    ...    ...
# 2015-12-24   17.27   52.71  182.47  66.60  32.48  54.82
# 2015-12-28   17.13   52.38  181.62  66.38  32.17  54.68
# 2015-12-29   17.28   52.98  183.53  67.07  32.55  55.29
# 2015-12-30   17.05   52.30  182.01  66.59  32.23  54.89
# 2015-12-31   16.83   51.75  180.23  66.03  31.81  54.36
#
# [2517 rows x 6 columns]

# %%
returns = pd.DataFrame()

# %%
bank_stock.xs(key="Close",axis=1,level="Stock Info")
# Out:
# Bank Ticker    bac       c      gs    jpm     ms    wfc
# Date
# 2006-01-03   47.08  492.90  128.87  40.19  58.31  31.90
# 2006-01-04   46.58  483.80  127.09  39.62  58.35  31.53
# 2006-01-05   46.64  486.20  127.04  39.74  58.51  31.50
# 2006-01-06   46.57  486.20  128.84  40.02  58.57  31.68
# 2006-01-09   46.60  483.90  130.39  40.67  59.19  31.68
# ...            ...     ...     ...    ...    ...    ...
# 2015-12-24   17.27   52.71  182.47  66.60  32.48  54.82
# 2015-12-28   17.13   52.38  181.62  66.38  32.17  54.68
# 2015-12-29   17.28   52.98  183.53  67.07  32.55  55.29
# 2015-12-30   17.05   52.30  182.01  66.59  32.23  54.89
# 2015-12-31   16.83   51.75  180.23  66.03  31.81  54.36
#
# [2517 rows x 6 columns]

# %%
for tick in tickers:
    returns[tick+" Returns"] = bank_stock[tick]["Close"].pct_change()

# %%
returns
# Out:
#             bac Returns  c Returns  gs Returns  jpm Returns  ms Returns  \
# Date
# 2006-01-03          NaN        NaN         NaN          NaN         NaN
# 2006-01-04    -0.010620  -0.018462   -0.013812    -0.014183    0.000686
# 2006-01-05     0.001288   0.004961   -0.000393     0.003029    0.002742
# 2006-01-06    -0.001501   0.000000    0.014169     0.007046    0.001025
# 2006-01-09     0.000644  -0.004731    0.012030     0.016242    0.010586
# ...                 ...        ...         ...          ...         ...
# 2015-12-24    -0.004037   0.001520   -0.002624    -0.001948   -0.003681
# 2015-12-28    -0.008107  -0.006261   -0.004658    -0.003303   -0.009544
# 2015-12-29     0.008757   0.011455    0.010516     0.010395    0.011812
# 2015-12-30    -0.013310  -0.012835   -0.008282    -0.007157   -0.009831
# 2015-12-31    -0.012903  -0.010516   -0.009780    -0.008410   -0.013031
#
#             wfc Returns
# Date
# 2006-01-03          NaN
# 2006-01-04    -0.011599
# ...

# %%
sns.pairplot(returns[1:])

# %%
returns.min()
# Out:
# bac Returns   -0.289694
# c Returns     -0.899107
# gs Returns    -0.189596
# jpm Returns   -0.207274
# ms Returns    -0.258929
# wfc Returns   -0.238223
# dtype: float64

# %%
returns.max()
# Out:
# bac Returns    0.352691
# c Returns      8.769912
# gs Returns     0.264678
# jpm Returns    0.250967
# ms Returns     0.869835
# wfc Returns    0.327645
# dtype: float64

# %%
returns["bac Returns"].argmin()
# returns time stamp
# Out:
# 766

# %%
returns.idxmin()
# returns indices minimum value on the "Returns" of the each banks
# Out:
# bac Returns   2009-01-20
# c Returns     2011-05-06
# gs Returns    2009-01-20
# jpm Returns   2009-01-20
# ms Returns    2008-10-09
# wfc Returns   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# bac Returns   2009-04-09
# c Returns     2011-05-09
# gs Returns    2008-11-24
# jpm Returns   2009-01-21
# ms Returns    2008-10-13
# wfc Returns   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# bac Returns    0.036650
# c Returns      0.179969
# gs Returns     0.025346
# jpm Returns    0.027656
# ms Returns     0.037820
# wfc Returns    0.030233
# dtype: float64

# %%
returns.loc["2015-01-01":"2015-12-31"].std()
# "returns.ix" is now been changes to "loc"
# they all have same risk profile with Wells Fargo is being least risky 
# and "Morgan Stanley"/"BAC" were riskiest
# Out:
# bac Returns    0.016163
# c Returns      0.015289
# gs Returns     0.014046
# jpm Returns    0.014017
# ms Returns     0.016249
# wfc Returns    0.012591
# dtype: float64

# %%
sns.distplot(returns.loc["2015-01-01":"2015-12-31"]["ms Returns"],color="green",bins=50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='ms Returns', ylabel='Density'>

# %%
dfs = returns.loc["2015-01-01":"2015-12-31"]["ms Returns"]
# dfs.iplot(kind="distplot")
dfs.iplot(kind="bar")
# Out:
# <div>                            <div id="fa335d76-3a27-4ddc-8177-f9989de4945e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# dfs

# %%
sns.displot(returns.loc["2008-01-01":"2008-12-31"]["c Returns"],color="red",bins=65)

# %%
close = pd.DataFrame()
for tick in tickers:
    close[tick + "  Close"] = bank_stock[tick]["Close"]

# %%
close
# Out:
#             bac  Close  c  Close  gs  Close  jpm  Close  ms  Close  wfc  Close
# Date
# 2006-01-03       47.08    492.90     128.87       40.19      58.31       31.90
# 2006-01-04       46.58    483.80     127.09       39.62      58.35       31.53
# 2006-01-05       46.64    486.20     127.04       39.74      58.51       31.50
# 2006-01-06       46.57    486.20     128.84       40.02      58.57       31.68
# 2006-01-09       46.60    483.90     130.39       40.67      59.19       31.68
# ...                ...       ...        ...         ...        ...         ...
# 2015-12-24       17.27     52.71     182.47       66.60      32.48       54.82
# 2015-12-28       17.13     52.38     181.62       66.38      32.17       54.68
# 2015-12-29       17.28     52.98     183.53       67.07      32.55       55.29
# 2015-12-30       17.05     52.30     182.01       66.59      32.23       54.89
# 2015-12-31       16.83     51.75     180.23       66.03      31.81       54.36
#
# ...

# %%
close.iplot()
# Out:
# <div>                            <div id="175abce8-911d-404a-b030-b52611a21688" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
for tick in tickers:
    bank_stock[tick]["Close"].plot(label=tick,figsize=(12,4))
plt.legend()

# %%
bank_stock.xs(key="Close",axis=1,level="Stock Info").plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bank_stock.xs(key="Close",axis=1,level="Stock Info").iplot()
# Out:
# <div>                            <div id="ccc5e336-2032-471d-bf57-0a7ce44e34cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize=(12,4))
bac["Close"].loc["2008-01-01":"2008-12-31"].rolling(window=30).mean().plot(label="30 Day Moving Average")
bac["Close"].loc["2008-01-01":"2008-12-31"].plot(label = "BAC Close")
plt.legend()

# %%
sns.heatmap(bank_stock.xs(key="Close",axis =1,level = "Stock Info").corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(bank_stock.xs(key="Close",axis =1,level = "Stock Info").corr(),annot=True)

# %%
bank_stock["bac"]
# Out:
# Stock Info   Open   High    Low  Close    Volume
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700
# 2006-01-04  47.00  47.24  46.45  46.58  17757900
# 2006-01-05  46.58  46.83  46.32  46.64  14970900
# 2006-01-06  46.80  46.91  46.35  46.57  12599800
# 2006-01-09  46.72  46.97  46.36  46.60  15620000
# ...           ...    ...    ...    ...       ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415
# 2015-12-28  17.22  17.23  16.98  17.13  41777497
# 2015-12-29  17.25  17.35  17.16  17.28  45670376
# 2015-12-30  17.20  17.24  17.04  17.05  35066378
# 2015-12-31  17.01  17.07  16.83  16.83  47152968
#
# [2517 rows x 5 columns]

# %%
# bank_stock["bac"].iplot(kind="Candle",x=["Open","High","Low"],y="Date")
close_corr=bank_stock.xs(key="Close",axis =1,level = "Stock Info").corr()

# %%
close_corr
# Out:
# Bank Ticker       bac         c        gs       jpm        ms       wfc
# Bank Ticker
# bac          1.000000  0.971514  0.550950  0.103896  0.944219  0.008567
# c            0.971514  1.000000  0.434171  0.003540  0.933605 -0.068441
# gs           0.550950  0.434171  1.000000  0.685280  0.683834  0.499901
# jpm          0.103896  0.003540  0.685280  1.000000  0.250441  0.940279
# ms           0.944219  0.933605  0.683834  0.250441  1.000000  0.131864
# wfc          0.008567 -0.068441  0.499901  0.940279  0.131864  1.000000

# %%
close_corr.iplot()
# Out:
# <div>                            <div id="5de89fe4-8215-44aa-8859-dba4cffeb713" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
close_corr.iplot(kind="heatmap",colorscale="rdylbu")
# Out:
# <div>                            <div id="5b3cdd0f-68ab-411f-8a36-3a89f49f3d5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
bac15 = bac[["Open","High","Low","Close"]].loc["2015-01-01":"2016-01-01"]

# %%
bac15
# Out:
# Stock Info   Open   High    Low  Close
# Date
# 2015-01-02  17.99  18.03  17.68  17.90
# 2015-01-05  17.78  17.81  17.29  17.38
# 2015-01-06  17.42  17.44  16.78  16.86
# 2015-01-07  17.14  17.18  16.87  16.94
# 2015-01-08  17.16  17.34  17.10  17.29
# ...           ...    ...    ...    ...
# 2015-12-24  17.32  17.38  17.22  17.27
# 2015-12-28  17.22  17.23  16.98  17.13
# 2015-12-29  17.25  17.35  17.16  17.28
# 2015-12-30  17.20  17.24  17.04  17.05
# 2015-12-31  17.01  17.07  16.83  16.83
#
# [252 rows x 4 columns]

# %%
bac15.iplot(kind="candle")
# Out:
# <div>                            <div id="bd2deeba-b66b-4a7b-9e2f-e2ed0d37d4f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ms["Close"].loc["2015-01-01":"2016-01-01"].ta_plot(study="sma",periods=[13,21,55])
# Out:
# <div>                            <div id="8eeddfa6-9321-42f7-a112-164f944470df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
bac["Close"].loc["2015-01-01":"2016-01-01"].ta_plot(study="boll")
# Out:
# <div>                            <div id="6eec6558-029d-4acf-89c3-3267eceff89d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
