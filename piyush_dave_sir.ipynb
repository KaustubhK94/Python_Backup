# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# df = pd.read_excel("C:/Users/kaustubh kapare/Downloads/heart_assignment.xlsx")

# %%
df
# Out:
#     Smoking AlcoholDrinking Stroke Heart Disease        Unnamed: 4 Unnamed: 5  \
# 0       Yes              No     No            No               NaN        NaN
# 1        No              No    Yes            No               NaN        NaN
# 2       Yes              No     No            No               NaN        NaN
# 3        No              No     No            No               NaN        NaN
# 4        No              No     No            No  Alcohol Drinking        NaN
# ..      ...             ...    ...           ...               ...        ...
# 494      No              No     No            No               NaN        NaN
# 495      No              No     No            No               NaN        NaN
# 496     Yes              No     No            No               NaN        NaN
# 497     Yes              No     No            No               NaN        NaN
# 498      No              No     No            No               NaN        NaN
#
# ...

# %%
df["Smoking"].value_counts()
# Out:
# No     286
# Yes    213
# Name: Smoking, dtype: int64

# %%
df["Heart Disease"].value_counts()
# Out:
# No     426
# Yes     73
# Name: Heart Disease, dtype: int64

# %%
df["AlcoholDrinking"].value_counts()
# Out:
# No     483
# Yes     16
# Name: AlcoholDrinking, dtype: int64

# %%
df[df["Smoking"]=="Yes"]
# Out:
#     Smoking AlcoholDrinking Stroke Heart Disease Unnamed: 4 Unnamed: 5  \
# 0       Yes              No     No            No        NaN        NaN
# 2       Yes              No     No            No        NaN        NaN
# 5       Yes              No     No           Yes        Yes         NO
# 7       Yes              No     No            No        NaN        NaN
# 10      Yes              No     No           Yes        NaN        NaN
# ..      ...             ...    ...           ...        ...        ...
# 480     Yes              No    Yes            No        NaN        NaN
# 484     Yes              No    Yes            No        NaN        NaN
# 492     Yes              No     No            No        NaN        NaN
# 496     Yes              No     No            No        NaN        NaN
# 497     Yes              No     No            No        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9 Unnamed: 10 Unnamed: 11
# ...

# %%
df2 = df[["Smoking","Heart Disease"]]
# df2 = df[["Smoking"]["Heart Disease"]]

# %%
# df2["new"]

# %%
df2
# Out:
#     Smoking Heart Disease
# 0       Yes            No
# 1        No            No
# 2       Yes            No
# 3        No            No
# 4        No            No
# ..      ...           ...
# 494      No            No
# 495      No            No
# 496     Yes            No
# 497     Yes            No
# 498      No            No
#
# [499 rows x 2 columns]

# %%
#
df["Smoking"].equals(df["Heart Disease"])
# Out:
# False

# %%
df["Heart Disease"] == "Yes"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# Name: Heart Disease, Length: 499, dtype: bool

# %%
# df["Heart Disease"].apply(tp)

# %%
details = {"column1":[1,2,3,4],"column2":[7,4,2,9],"column3":[3,4,5,6]}

# %%
df = pd.DataFrame(details)

# %%
df
# Out:
#    column1  column2  column3
# 0        1        7        3
# 1        2        4        4
# 2        3        2        5
# 3        4        9        6

# %%
df["new"] = df.apply(lambda x:x["column1"] if x["column1"] <= x["column2"] and x["column1"]<= x["column3"] else np.nan, axis=1)

# %%
df
# Out:
#    column1  column2  column3  new
# 0        1        7        3  1.0
# 1        2        4        4  2.0
# 2        3        2        5  NaN
# 3        4        9        6  4.0

# %%
# df2["new"] = df.apply(lambda x:x["Smoking"] if x["Smoking"] == x["Heart Disease"] else np.nan , axis=1 )

# %%
df2
# Out:
#     Smoking Heart Disease
# 0       Yes            No
# 1        No            No
# 2       Yes            No
# 3        No            No
# 4        No            No
# ..      ...           ...
# 494      No            No
# 495      No            No
# 496     Yes            No
# 497     Yes            No
# 498      No            No
#
# [499 rows x 2 columns]

# %%
 def tp(a,b):
        if df[a] == df[b]:
            return 1
        else:
            return 0
#     count = 0
#     for i in data == "Yes":
#         i = i + 1
#     return i

# %%
df2["new"] = df2[["Smoking","Heart Disease"]].apply(tp("Smoking","Heart Disease"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [84], in <cell line: 1>()
# ----> 1 df2["new"] = df2[["Smoking","Heart Disease"]].apply(tp("Smoking","Heart Disease"))
#
# Input In [82], in tp(a, b)
#       1 def tp(a,b):
# ----> 2        if df[a] == df[b]:
#       3            return 1
#       4        else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
