# %%
import seaborn as sns
import scipy.stats as stat
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips["total_bill"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.displot(tips["total_bill"],kde=True)
# shows us the distribution of the univariate set of observations
# kernal density estimatation

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.displot(tips["total_bill"],kde = True,bins=30)
# kernal density estimatation
# choose bin no appropriate suiting your data

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.displot(tips["total_bill"],kde =True,bins=100)

# %%
sns.histplot(tips["total_bill"],kde = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.jointplot(x="total_bill",y="tip",data=tips,kind="scatter")
# matches two distplot with bivariate data
# as you go higher in bill you go higher in tip

# %%
# sns.set(style = "darkgrid",color_codes = True)
sns.jointplot(x="total_bill",y="tip",data=tips,kind="hex")

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.jointplot(x="total_bill",y="tip",data=tips,kind="kde",shade = True)

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.jointplot(x="total_bill",y="tip",data=tips,kind="reg")
# matches two displot with different variables
# as you go higher in bill you go higher in tip
# it is showing best fit line to the data

# %%
sns.pairplot(tips)

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.pairplot(tips,hue="sex",palette="coolwarm")

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.rugplot(tips["total_bill"])
# plots a dash point for a unique point in the univariate distribution
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.distplot(tips["total_bill"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
# in distplot it is actually calculating the points in rugplot and plot it in distplot

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.kdeplot(tips['total_bill'],shade= True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(x="total_bill",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.set(style = "darkgrid",color_codes = True)
sns.kdeplot(x="total_bill",y="tip",data=tips,shade = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
#Create dataset
dataset = np.random.randn(25)
sns.set(style = "darkgrid",color_codes = True)
# Create another rugplot
sns.rugplot(dataset)
# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2
# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)
# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'
bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2
# Create an empty kernel list
kernel_list = []
# Plot each basis function
for data_point in dataset:
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# To get the kde plot we can sum these basis functions.
sns.set(style = "darkgrid",color_codes = True)
# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)
# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')
# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')
# Get rid of y-tick marks
plt.yticks([])
# Set title
plt.suptitle("Sum of the Basis Functions")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Functions')

# %%
# Categorical plot

# %%
sns.barplot(x="sex",y="total_bill",data=tips)
# average total bill
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.std)
# average total bill
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x="sex",data=tips)
# counts the occurences
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='day',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.boxplot(x="sex",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips)
# Dots are outliers
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,hue="smoker")
# Dots are outliers
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex",split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue="sex",split=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2805: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
sns.swarmplot(x="day",y="total_bill",data=tips,color="blue")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.factorplot(x="day",y="total_bill",data=tips,kind="bar")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x="day",y="total_bill",data=tips,kind="violin")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
flights = sns.load_dataset("flights")

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tc = tips.corr()

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc,annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
fp =flights.pivot_table(index="month",columns="year",values="passengers")

# %%
fp
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fp)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.displot(data=flights["passengers"],kde = True,bins=30)

# %%
sns.scatterplot(x="passengers",y="month",data=flights)
# Out:
# <AxesSubplot:xlabel='passengers', ylabel='month'>

# %%
sns.scatterplot(x="month",y="passengers",data=flights)
# Out:
# <AxesSubplot:xlabel='month', ylabel='passengers'>

# %%
sns.heatmap(fp,cmap="magma",linecolor="White",linewidth=3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(fp,cmap="coolwarm",linecolor="black",linewidth=3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(fp)
# tries to cluster columns and rows together based on some similarity

# %%
sns.clustermap(fp,cmap = "coolwarm")
# tries to cluster columns and rows together based on some similarity

# %%
sns.clustermap(fp,cmap = "coolwarm",standard_scale=1)
# tries to cluster columns and rows together based on some similarity

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)   ### Diagonally all are distplots
g.map_upper(plt.scatter)   ### Above the diagonal all are scatter plot
g.map_lower(sns.kdeplot)   ### and the plots below are KDE plots
#  gives us better control over
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import sklearn
kde = sklearn.neighbors.KernelDensity(bandwidth = 1.0)

# %%
kde
# Out:
# KernelDensity()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
g = sns.FacetGrid(data= tips,col="time",row="smoker")
g.map(sns.distplot,"total_bill")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
g = sns.FacetGrid(data= tips,col="time",row="smoker")
g.map(sns.scatterplot,"total_bill","tip")

# %%
n = np.arange(1,7)

# %%
import pandas as pd

# %%
t = pd.DataFrame(n)

# %%
t["Pr"] = t.apply(lambda x:x/6)

# %%
t
# Out:
#    0        Pr
# 0  1  0.166667
# 1  2  0.333333
# 2  3  0.500000
# 3  4  0.666667
# 4  5  0.833333
# 5  6  1.000000

# %%
t["probability"] = t.apply(lambda x:1/6,axis=1)

# %%
t
# Out:
#    0        Pr  probability
# 0  1  0.166667     0.166667
# 1  2  0.333333     0.166667
# 2  3  0.500000     0.166667
# 3  4  0.666667     0.166667
# 4  5  0.833333     0.166667
# 5  6  1.000000     0.166667

# %%
sns.distplot(t[0],kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='0', ylabel='Density'>

# %%
fig = plt.figure()
axe = fig.add_axes([0.1,0.1,0.8,0.8])
axe.plot(t[0],t["probability"])

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(t[0],t["Pr"])
axes[1].plot(t[0],t["probability"])
plt.tight_layout()

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
#Create dataset
dataset = np.random.randn(25)
print(dataset)
# Create another rugplot
# sns.rugplot(dataset)
# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2
print(x_min)
print(x_max)
# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)
print(x_axis)
# # Set up the bandwidth, for info on this:
# url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'
bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2
print(bandwidth)
# # Create an empty kernel list
kernel_list = []
# # Plot each basis function
for data_point in dataset:
#     # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)
plt.ylim(0,1)
# Out:
# [-0.51471734 -0.54364198  2.30184151 -0.9260093  -0.13343159  2.04136099
#  -0.12504077  0.46091629  0.6478302   1.72100794  0.30695405 -0.77136168
#  -0.7973342  -1.25322375 -1.13704565 -0.58119145  0.71224766 -0.55267711
#  -0.49136687 -1.49480189  1.47363521  0.68282669 -0.25400907 -0.97611769
#  -1.52687226]
# -3.5268722604169516
# 4.301841508684472
# [-3.52687226 -3.44779434 -3.36871643 -3.28963851 -3.21056059 -3.13148268
#  -3.05240476 -2.97332684 -2.89424893 -2.81517101 -2.73609309 -2.65701517
#  -2.57793726 -2.49885934 -2.41978142 -2.34070351 -2.26162559 -2.18254767
#  -2.10346976 -2.02439184 -1.94531392 -1.86623601 -1.78715809 -1.70808017
#  -1.62900226 -1.54992434 -1.47084642 -1.39176851 -1.31269059 -1.23361267
#  -1.15453475 -1.07545684 -0.99637892 -0.917301   -0.83822309 -0.75914517
#  -0.68006725 -0.60098934 -0.52191142 -0.4428335  -0.36375559 -0.28467767
#  -0.20559975 -0.12652184 -0.04744392  0.031634    0.11071192  0.18978983
# ...

# %%
dataset = np.random.randn(25)
print(dataset)
bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2
print(bandwidth)
kernel_list = []
x_min = dataset.min() - 2
x_max = dataset.max() + 2
print(x_min)
print(x_max)
x_axis = np.linspace(x_min,x_max,100)
print(x_axis)
# # Plot each basis function
for data_point in dataset:
#     # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    print(kernel)
    kernel_list.append(kernel)
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)
kernel_list
# Out:
# [ 1.59960470e+00 -5.01191599e-01 -8.84796996e-01  1.46236266e+00
#  -1.56788409e+00 -5.74028667e-01  3.36607523e-01 -7.72659801e-01
#   1.09866426e-01  4.74102137e-04  6.07168700e-01 -1.38194553e+00
#   1.10194973e+00  9.10886923e-01 -9.05093898e-01  4.07775300e-01
#  -3.16989927e-01 -8.62124724e-01  1.08039710e+00  3.96527844e+00
#  -1.26407270e+00 -9.83001899e-02 -1.66363700e-01 -4.35123425e-01
#  -5.52623751e-01]
# 0.6521826238895787
# -3.567884087185444
# 5.9652784434741974
# [-3.56788409e+00 -3.47158952e+00 -3.37529495e+00 -3.27900037e+00
#  -3.18270580e+00 -3.08641123e+00 -2.99011666e+00 -2.89382209e+00
#  -2.79752752e+00 -2.70123295e+00 -2.60493838e+00 -2.50864381e+00
#  -2.41234923e+00 -2.31605466e+00 -2.21976009e+00 -2.12346552e+00
#  -2.02717095e+00 -1.93087638e+00 -1.83458181e+00 -1.73828724e+00
#  -1.64199267e+00 -1.54569810e+00 -1.44940352e+00 -1.35310895e+00
#  -1.25681438e+00 -1.16051981e+00 -1.06422524e+00 -9.67930670e-01
# ...

# %%
# x_min = dataset.min() - 2
# x_max = dataset.max() + 2
# x_axis = np.linspace(x_min,x_max,100)
# stats.norm(0.76065393,0.5615711).pdf(x_axis)
