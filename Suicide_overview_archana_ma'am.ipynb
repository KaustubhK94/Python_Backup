# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# from plotly import __version__
# print(__version__)
# import cufflinks as cf
# from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
# init_notebook_mode(connected= True)
# cf.go_offline()

# %%
sns.set(style = "darkgrid",color_codes = True)

# %%
pd.pandas.set_option("display.max_columns",None)

# %%
df = pd.read_csv("C:/Users/kaustubh kapare/Downloads/Suicide_overview.csv")

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %%
gdp_for_year = df[" gdp_for_year ($) "].str.replace(",","")
# converted gdp_for _year into numerical

# %%
##### My own Fucntion..!!!!!!
def num_feat(dfs):
    dslst=[]
    for col in dfs.columns:
        if dfs[col].dtypes !="object":
            dslst.append(col)
    return dslst

# %%
num_feat(df)
# Out:
# ['year',
#  'suicides_no',
#  'population',
#  'suicides/100k pop',
#  'HDI for year',
#  'gdp_per_capita ($)']

# %%
df[num_feat]
# Out:
#        year  suicides_no  population  suicides/100k pop  HDI for year  \
# 0      1987           21      312900               6.71           NaN
# 1      1987           16      308000               5.19           NaN
# 2      1987           14      289700               4.83           NaN
# 3      1987            1       21800               4.59           NaN
# 4      1987            9      274300               3.28           NaN
# ...     ...          ...         ...                ...           ...
# 27815  2014          107     3620833               2.96         0.675
# 27816  2014            9      348465               2.58         0.675
# 27817  2014           60     2762158               2.17         0.675
# 27818  2014           44     2631600               1.67         0.675
# 27819  2014           21     1438935               1.46         0.675
#
#        gdp_per_capita ($)
# 0                     796
# 1                     796
# 2                     796
# ...

# %%
num_df = df.select_dtypes(include=["int64","float64"])
## another method....

# %%
num_df
# Out:
#        year  suicides_no  population  suicides/100k pop  HDI for year  \
# 0      1987           21      312900               6.71           NaN
# 1      1987           16      308000               5.19           NaN
# 2      1987           14      289700               4.83           NaN
# 3      1987            1       21800               4.59           NaN
# 4      1987            9      274300               3.28           NaN
# ...     ...          ...         ...                ...           ...
# 27815  2014          107     3620833               2.96         0.675
# 27816  2014            9      348465               2.58         0.675
# 27817  2014           60     2762158               2.17         0.675
# 27818  2014           44     2631600               1.67         0.675
# 27819  2014           21     1438935               1.46         0.675
#
#        gdp_per_capita ($)
# 0                     796
# 1                     796
# 2                     796
# ...

# %%
gdp_for_year = df[" gdp_for_year ($) "].str.replace(",","")
# converted gdp_for _year into numerical

# %%
num_df["gdp_for_year"] = gdp_for_year

# %%
num_df # now gdp for year column/feature added
# Out:
#        year  suicides_no  population  suicides/100k pop  HDI for year  \
# 0      1987           21      312900               6.71           NaN
# 1      1987           16      308000               5.19           NaN
# 2      1987           14      289700               4.83           NaN
# 3      1987            1       21800               4.59           NaN
# 4      1987            9      274300               3.28           NaN
# ...     ...          ...         ...                ...           ...
# 27815  2014          107     3620833               2.96         0.675
# 27816  2014            9      348465               2.58         0.675
# 27817  2014           60     2762158               2.17         0.675
# 27818  2014           44     2631600               1.67         0.675
# 27819  2014           21     1438935               1.46         0.675
#
#        gdp_per_capita ($) gdp_for_year
# 0                     796   2156624900
# 1                     796   2156624900
# ...

# %%
num_df.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
sns.pairplot(data=num_df)

# %%
feat_na = [feat for feat in df.columns if df[feat].isnull().sum()>1 ]

# %%
feat_na
# Out:
# ['HDI for year']

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
cor = df.corr()

# %%
cor
# Out:
#                         year  suicides_no  population  suicides/100k pop  \
# year                1.000000    -0.004546    0.008850          -0.039037
# suicides_no        -0.004546     1.000000    0.616162           0.306604
# population          0.008850     0.616162    1.000000           0.008285
# suicides/100k pop  -0.039037     0.306604    0.008285           1.000000
# HDI for year        0.366786     0.151399    0.102943           0.074279
# gdp_per_capita ($)  0.339134     0.061330    0.081510           0.001785
#
#                     HDI for year  gdp_per_capita ($)
# year                    0.366786            0.339134
# suicides_no             0.151399            0.061330
# population              0.102943            0.081510
# suicides/100k pop       0.074279            0.001785
# HDI for year            1.000000            0.771228
# gdp_per_capita ($)      0.771228            1.000000

# %%
fig,ax = plt.subplots(figsize = (10,10))
sns.heatmap(cor,annot=True,cmap="magma",linecolor="white",linewidth=1,ax=ax)
# Out:
# <AxesSubplot:>

# %%
df["age"].value_counts()
# Out:
# 15-24 years    4642
# 35-54 years    4642
# 75+ years      4642
# 25-34 years    4642
# 55-74 years    4642
# 5-14 years     4610
# Name: age, dtype: int64

# %%
# df.dropna(inplace=True)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
# fig,ax = plt.subplots(figsize = (10,10))
plt.figure(figsize=(10,10))
sns.heatmap(cor,annot=True,cmap="coolwarm",linecolor="white",linewidth=1)
# Out:
# <AxesSubplot:>

# %%
countries=df["country"].unique()

# %%
countries
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
len(df["country"].unique())
# Out:
# 101

# %%
fig,ax = plt.subplots(figsize = (10,20))
sns.barplot(y = df["country"].unique(),x=df.groupby(["country"]).suicides_no.sum(),ax=ax)
# Out:
# <AxesSubplot:xlabel='suicides_no'>

# %%
# df.groupby("country")
dfs = df[["country","year","age","suicides_no","sex"]]
dfs
# Out:
#           country  year          age  suicides_no     sex
# 0         Albania  1987  15-24 years           21    male
# 1         Albania  1987  35-54 years           16    male
# 2         Albania  1987  15-24 years           14  female
# 3         Albania  1987    75+ years            1    male
# 4         Albania  1987  25-34 years            9    male
# ...           ...   ...          ...          ...     ...
# 27815  Uzbekistan  2014  35-54 years          107  female
# 27816  Uzbekistan  2014    75+ years            9  female
# 27817  Uzbekistan  2014   5-14 years           60    male
# 27818  Uzbekistan  2014   5-14 years           44  female
# 27819  Uzbekistan  2014  55-74 years           21  female
#
# [27820 rows x 5 columns]

# %%
dfs["age"]
# Out:
# 0        15-24 years
# 1        35-54 years
# 2        15-24 years
# 3          75+ years
# 4        25-34 years
#             ...
# 27815    35-54 years
# 27816      75+ years
# 27817     5-14 years
# 27818     5-14 years
# 27819    55-74 years
# Name: age, Length: 27820, dtype: object

# %%
dfs["age"].str.replace("years","")
# Out:
# 0        15-24
# 1        35-54
# 2        15-24
# 3          75+
# 4        25-34
#           ...
# 27815    35-54
# 27816      75+
# 27817     5-14
# 27818     5-14
# 27819    55-74
# Name: age, Length: 27820, dtype: object

# %%
dfs["age"].unique()
# Out:
# array(['15-24 years', '35-54 years', '75+ years', '25-34 years',
#        '55-74 years', '5-14 years'], dtype=object)

# %%
dfs["suicides_no"]
# Out:
# 0         21
# 1         16
# 2         14
# 3          1
# 4          9
#         ...
# 27815    107
# 27816      9
# 27817     60
# 27818     44
# 27819     21
# Name: suicides_no, Length: 27820, dtype: int64

# %%
df['suicides_no']
# Out:
# 0         21
# 1         16
# 2         14
# 3          1
# 4          9
#         ...
# 27815    107
# 27816      9
# 27817     60
# 27818     44
# 27819     21
# Name: suicides_no, Length: 27820, dtype: int64

# %%
fig,ax = plt.subplots(figsize = (7,7))
sns.barplot(x=df["age"],y=df["suicides_no"],ax=ax)
# Out:
# <AxesSubplot:xlabel='age', ylabel='suicides_no'>

# %%
fig,ax = plt.subplots(figsize = (7,7))
sns.scatterplot(x=df["age"],y=df["suicides_no"],ax=ax)
# Out:
# <AxesSubplot:xlabel='age', ylabel='suicides_no'>

# %%
fig,ax = plt.subplots(figsize = (7,7))
sns.scatterplot(x=df["generation"],y=df["suicides_no"],ax=ax,hue=df["sex"])
# Out:
# <AxesSubplot:xlabel='generation', ylabel='suicides_no'>

# %%
fig,ax = plt.subplots(figsize = (7,7))
sns.scatterplot(x=df["age"],y=df["suicides_no"],ax=ax,hue=df['sex'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='suicides_no'>

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
fig,ax = plt.subplots(figsize = (7,7))
sns.scatterplot(x=df['year'], y=df['suicides_no'], ax=ax, hue=df['sex'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='suicides_no'>
