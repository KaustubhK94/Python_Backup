# %%
import pandas as pd

# %%
import numpy as np

# %%
import plotly.graph_objects as go

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# C:\Users\kaustubh kapare\Downloads
df = pd.read_csv("C:/Users/kaustubh kapare/Downloads/lapTimes/lapTimes.csv")
driverdf = pd.read_csv("C:/Users/kaustubh kapare/Downloads/lapTimes/drivers.csv",encoding='unicode_escape')
raceid = pd.read_csv("C:/Users/kaustubh kapare/Downloads/lapTimes/races.csv")

# %% [markdown]
# df

# %%
df
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 0          841        20    1         1  1:38.109         98109
# 1          841        20    2         1  1:33.006         93006
# 2          841        20    3         1  1:32.713         92713
# 3          841        20    4         1  1:32.803         92803
# 4          841        20    5         1  1:32.342         92342
# ...        ...       ...  ...       ...       ...           ...
# 426628     988       825   50        13  1:43.928        103928
# 426629     988       825   51        13  1:44.138        104138
# 426630     988       825   52        13  1:43.934        103934
# 426631     988       825   53        13  1:44.164        104164
# 426632     988       825   54        13  1:44.285        104285
#
# [426633 rows x 6 columns]

# %%
df["raceId"]
# Out:
# 0         841
# 1         841
# 2         841
# 3         841
# 4         841
#          ...
# 426628    988
# 426629    988
# 426630    988
# 426631    988
# 426632    988
# Name: raceId, Length: 426633, dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
driverdf
# Out:
#      driverId        driverRef  number code  forename     surname         dob  \
# 0           1         hamilton    44.0  HAM     Lewis    Hamilton  07/01/1985
# 1           2         heidfeld     NaN  HEI      Nick    Heidfeld  10/05/1977
# 2           3          rosberg     6.0  ROS      Nico     Rosberg  27/06/1985
# 3           4           alonso    14.0  ALO  Fernando      Alonso  29/07/1981
# 4           5       kovalainen     NaN  KOV    Heikki  Kovalainen  19/10/1981
# ..        ...              ...     ...  ...       ...         ...         ...
# 837       838        vandoorne     2.0  VAN   Stoffel   Vandoorne  26/03/1992
# 838       839             ocon    31.0  OCO   Esteban        Ocon  17/09/1996
# 839       840           stroll    18.0  STR     Lance      Stroll  29/10/1998
# 840       841       giovinazzi    36.0  GIO   Antonio  Giovinazzi  14/12/1993
# 841       843  brendon_hartley    39.0  HAR   Brendon     Hartley  10/11/1989
#
# ...

# %%
sns.heatmap(driverdf.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
raceid
# Out:
#      raceId  year  round  circuitId                      name        date  \
# 0         1  2009      1          1     Australian Grand Prix  2009-03-29
# 1         2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2         3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3         4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4         5  2009      5          4        Spanish Grand Prix  2009-05-10
# ..      ...   ...    ...        ...                       ...         ...
# 992    1005  2018     17         22       Japanese Grand Prix  2018-10-07
# 993    1006  2018     18         69  United States Grand Prix  2018-10-21
# 994    1007  2018     19         32        Mexican Grand Prix  2018-10-28
# 995    1008  2018     20         18      Brazilian Grand Prix  2018-11-11
# 996    1009  2018     21         24      Abu Dhabi Grand Prix  2018-11-25
#
#          time                                                url
# ...

# %%
race_df = raceid.drop(["url","time"],axis=1)

# %%
race_df
# Out:
#      raceId  year  round  circuitId                      name        date
# 0         1  2009      1          1     Australian Grand Prix  2009-03-29
# 1         2  2009      2          2      Malaysian Grand Prix  2009-04-05
# 2         3  2009      3         17        Chinese Grand Prix  2009-04-19
# 3         4  2009      4          3        Bahrain Grand Prix  2009-04-26
# 4         5  2009      5          4        Spanish Grand Prix  2009-05-10
# ..      ...   ...    ...        ...                       ...         ...
# 992    1005  2018     17         22       Japanese Grand Prix  2018-10-07
# 993    1006  2018     18         69  United States Grand Prix  2018-10-21
# 994    1007  2018     19         32        Mexican Grand Prix  2018-10-28
# 995    1008  2018     20         18      Brazilian Grand Prix  2018-11-11
# 996    1009  2018     21         24      Abu Dhabi Grand Prix  2018-11-25
#
# [997 rows x 6 columns]

# %%
dvr_df= driverdf.drop(["url","dob","code","number"],axis=1)

# %%
dvr_df
# Out:
#      driverId        driverRef  forename     surname    nationality
# 0           1         hamilton     Lewis    Hamilton        British
# 1           2         heidfeld      Nick    Heidfeld         German
# 2           3          rosberg      Nico     Rosberg         German
# 3           4           alonso  Fernando      Alonso        Spanish
# 4           5       kovalainen    Heikki  Kovalainen        Finnish
# ..        ...              ...       ...         ...            ...
# 837       838        vandoorne   Stoffel   Vandoorne        Belgian
# 838       839             ocon   Esteban        Ocon         French
# 839       840           stroll     Lance      Stroll       Canadian
# 840       841       giovinazzi   Antonio  Giovinazzi        Italian
# 841       843  brendon_hartley   Brendon     Hartley  New Zealander
#
# [842 rows x 5 columns]

# %%
sns.heatmap(dvr_df.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
# sns.pairplot(dvr_df)

# %%
# df2 = df.groupby("driverId")

# %%
# df2.describe()

# %%
df2 = df.set_index("driverId")
df2
# Out:
#           raceId  lap  position      time  milliseconds
# driverId
# 20           841    1         1  1:38.109         98109
# 20           841    2         1  1:33.006         93006
# 20           841    3         1  1:32.713         92713
# 20           841    4         1  1:32.803         92803
# 20           841    5         1  1:32.342         92342
# ...          ...  ...       ...       ...           ...
# 825          988   50        13  1:43.928        103928
# 825          988   51        13  1:44.138        104138
# 825          988   52        13  1:43.934        103934
# 825          988   53        13  1:44.164        104164
# 825          988   54        13  1:44.285        104285
#
# [426633 rows x 5 columns]

# %%
# pd.concat([df2,dvr_df])

# %%
tp = df2.groupby("driverId")
# pd.merge(df2,dvr_df,how="")

# %%
tp.head()
# Out:
#           raceId  lap  position      time  milliseconds
# driverId
# 20           841    1         1  1:38.109         98109
# 20           841    2         1  1:33.006         93006
# 20           841    3         1  1:32.713         92713
# 20           841    4         1  1:32.803         92803
# 20           841    5         1  1:32.342         92342
# ...          ...  ...       ...       ...           ...
# 843          985   55        13  1:43.162        103162
# 843          985   54        13  1:41.112        101112
# 843          985   53        14  1:40.142        100142
# 843          985   52        14  1:40.111        100111
# 843          985   51        14  1:40.097        100097
#
# [611 rows x 5 columns]

# %%
final_df = pd.merge(df2,dvr_df,how="inner",on="driverId")

# %%
final_df
# Out:
#         driverId  raceId  lap  position      time  milliseconds  \
# 0             20     841    1         1  1:38.109         98109
# 1             20     841    2         1  1:33.006         93006
# 2             20     841    3         1  1:32.713         92713
# 3             20     841    4         1  1:32.803         92803
# 4             20     841    5         1  1:32.342         92342
# ...          ...     ...  ...       ...       ...           ...
# 426628       843     988   50        15  1:44.204        104204
# 426629       843     988   51        15  1:44.171        104171
# 426630       843     988   52        15  1:43.897        103897
# 426631       843     988   53        15  1:44.249        104249
# 426632       843     988   54        15  1:44.741        104741
#
#               driverRef   forename  surname    nationality
# 0                vettel  Sebastian   Vettel         German
# 1                vettel  Sebastian   Vettel         German
# ...

# %%
f_one_df = pd.merge(final_df,race_df,how="inner",on="raceId")

# %%
f_one_df
# Out:
#         driverId  raceId  lap  position      time  milliseconds driverRef  \
# 0             20     841    1         1  1:38.109         98109    vettel
# 1             20     841    2         1  1:33.006         93006    vettel
# 2             20     841    3         1  1:32.713         92713    vettel
# 3             20     841    4         1  1:32.803         92803    vettel
# 4             20     841    5         1  1:32.342         92342    vettel
# ...          ...     ...  ...       ...       ...           ...       ...
# 426628        69     229   56        10  1:35.361         95361    badoer
# 426629        69     229   57        10  1:33.885         93885    badoer
# 426630        69     229   58        10  1:35.646         95646    badoer
# 426631        69     229   59        10  1:37.811         97811    badoer
# 426632        69     229   60        10  1:33.606         93606    badoer
#
#          forename surname nationality  year  round  circuitId  \
# ...

# %%
sns.pairplot(f_one_df)

# %%
f_one_df[["driverId","driverRef"]]
# Out:
#         driverId driverRef
# 0             20    vettel
# 1             20    vettel
# 2             20    vettel
# 3             20    vettel
# 4             20    vettel
# ...          ...       ...
# 426628        69    badoer
# 426629        69    badoer
# 426630        69    badoer
# 426631        69    badoer
# 426632        69    badoer
#
# [426633 rows x 2 columns]

# %%
#  Sebastian vettel's debut

# %%
f_one_df[f_one_df["surname"]=="Vettel"]["year"].min()
# Out:
# 2007

# %%
f_one_df[f_one_df["surname"]=="Vettel"]["date"].min()
# Out:
# '2007-06-17'

# %%
list(f_one_df[f_one_df["date"] == (f_one_df[f_one_df["surname"]=="Vettel"]["date"].min())]["name"])[0]
# Out:
# 'United States Grand Prix'

# %%
f_one_df[f_one_df["surname"]=="Vettel"]
# Out:
#         driverId  raceId  lap  position      time  milliseconds driverRef  \
# 0             20     841    1         1  1:38.109         98109    vettel
# 1             20     841    2         1  1:33.006         93006    vettel
# 2             20     841    3         1  1:32.713         92713    vettel
# 3             20     841    4         1  1:32.803         92803    vettel
# 4             20     841    5         1  1:32.342         92342    vettel
# ...          ...     ...  ...       ...       ...           ...       ...
# 217684        20     988   51         3  1:41.668        101668    vettel
# 217685        20     988   52         3  1:41.243        101243    vettel
# 217686        20     988   53         3  1:41.222        101222    vettel
# 217687        20     988   54         3  1:42.292        102292    vettel
# 217688        20     988   55         3  1:40.770        100770    vettel
#
#          forename surname nationality  year  round  circuitId  \
# ...

# %%
f_one_df[f_one_df["surname"]=="Vettel"]["name"]
# Out:
# 0         Australian Grand Prix
# 1         Australian Grand Prix
# 2         Australian Grand Prix
# 3         Australian Grand Prix
# 4         Australian Grand Prix
#                   ...
# 217684     Abu Dhabi Grand Prix
# 217685     Abu Dhabi Grand Prix
# 217686     Abu Dhabi Grand Prix
# 217687     Abu Dhabi Grand Prix
# 217688     Abu Dhabi Grand Prix
# Name: name, Length: 10723, dtype: object

# %%
f_one_df.loc[f_one_df["surname"]=="Vettel"]["date"] == f_one_df[f_one_df["surname"]=="Vettel"]["date"].min()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 217684    False
# 217685    False
# 217686    False
# 217687    False
# 217688    False
# Name: date, Length: 10723, dtype: bool

# %%
# f_one_df[f_one_df[f_one_df["surname"]=="Vettel"]["date"].min()

# %%
f_one_df[f_one_df["surname"]=="Vettel"]["date"]
# Out:
# 0         2011-03-27
# 1         2011-03-27
# 2         2011-03-27
# 3         2011-03-27
# 4         2011-03-27
#              ...
# 217684    2017-11-26
# 217685    2017-11-26
# 217686    2017-11-26
# 217687    2017-11-26
# 217688    2017-11-26
# Name: date, Length: 10723, dtype: object

# %%
# f_one_df[f_one_df["surname"]=="Vettel"]["date"] == f_one_df[f_one_df["surname"]=="Vettel"]["date"].min()["name"]

# %%
f_one_df[f_one_df["name"]=="Australian Grand Prix"]
# Out:
#         driverId  raceId  lap  position      time  milliseconds   driverRef  \
# 0             20     841    1         1  1:38.109         98109      vettel
# 1             20     841    2         1  1:33.006         93006      vettel
# 2             20     841    3         1  1:32.713         92713      vettel
# 3             20     841    4         1  1:32.803         92803      vettel
# 4             20     841    5         1  1:32.342         92342      vettel
# ...          ...     ...  ...       ...       ...           ...         ...
# 404937        21     224   28        14  1:40.680        100680  fisichella
# 404938        21     224   29        14  1:40.684        100684  fisichella
# 404939        21     224   30        13  1:41.807        101807  fisichella
# 404940        21     224   31        13  1:40.237        100237  fisichella
# 404941        21     224   32        13  1:41.584        101584  fisichella
#
# ...

# %%
f_one_df.loc[(f_one_df["surname"]=="Vettel") & (f_one_df["name"]=="Australian Grand Prix")]
# Out:
#         driverId  raceId  lap  position      time  milliseconds driverRef  \
# 0             20     841    1         1  1:38.109         98109    vettel
# 1             20     841    2         1  1:33.006         93006    vettel
# 2             20     841    3         1  1:32.713         92713    vettel
# 3             20     841    4         1  1:32.803         92803    vettel
# 4             20     841    5         1  1:32.342         92342    vettel
# ...          ...     ...  ...       ...       ...           ...       ...
# 199255        20     969   53         1  1:26.638         86638    vettel
# 199256        20     969   54         1  1:27.007         87007    vettel
# 199257        20     969   55         1  1:27.369         87369    vettel
# 199258        20     969   56         1  1:27.437         87437    vettel
# 199259        20     969   57         1  1:28.709         88709    vettel
#
#          forename surname nationality  year  round  circuitId  \
# ...

# %%
f_one_df.loc[(f_one_df["surname"]=="Vettel") & (f_one_df["name"]=="Australian Grand Prix")]["time"].min()
# Out:
# '1:26.638'

# %%
f_one_df.loc[(f_one_df["surname"]=="Vettel") & (f_one_df["name"]=="Monaco Grand Prix")]["time"].min()
# Out:
# '1:15.192'

# %%
# f_one_df.loc[(f_one_df["surname"]=="Vettel") & (f_one_df["name"]=="British Grand Prix")]["time"].min()

# %%
f_one_df.loc[(f_one_df["surname"]=="Vettel") & (f_one_df["name"]=="British Grand Prix")]
# Out:
#         driverId  raceId  lap  position      time  milliseconds driverRef  \
# 10723         20     849    1         1  1:54.623        114623    vettel
# 10724         20     849    2         1  1:50.924        110924    vettel
# 10725         20     849    3         1  1:50.838        110838    vettel
# 10726         20     849    4         1  1:51.013        111013    vettel
# 10727         20     849    5         1  1:51.421        111421    vettel
# ...          ...     ...  ...       ...       ...           ...       ...
# 208522        20     978   47         4  1:33.862         93862    vettel
# 208523        20     978   48         4  1:34.390         94390    vettel
# 208524        20     978   49         4  1:35.029         95029    vettel
# 208525        20     978   50         6  2:10.652        130652    vettel
# 208526        20     978   51         7  2:01.681        121681    vettel
#
#          forename surname nationality  year  round  circuitId  \
# ...

# %%
f_one_df[f_one_df["surname"]=="Vettel"]["date"].min()
# Out:
# '2007-06-17'

# %%
f_one_df["date"] == (f_one_df[f_one_df["surname"]=="Vettel"]["date"].min())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 426628    False
# 426629    False
# 426630    False
# 426631    False
# 426632    False
# Name: date, Length: 426633, dtype: bool

# %%
f_one_df[f_one_df["date"] == (f_one_df[f_one_df["surname"]=="Vettel"]["date"].min())]
# Out:
#         driverId  raceId  lap  position      time  milliseconds driverRef  \
# 112792        20      42    1        11  1:25.799         85799    vettel
# 112793        20      42    2        10  1:15.739         75739    vettel
# 112794        20      42    3        10  1:15.985         75985    vettel
# 112795        20      42    4        10  1:16.149         76149    vettel
# 112796        20      42    5        10  1:15.890         75890    vettel
# ...          ...     ...  ...       ...       ...           ...       ...
# 114075        26      42   67        14  1:18.165         78165     speed
# 114076        26      42   68        14  1:15.673         75673     speed
# 114077        26      42   69        13  1:15.492         75492     speed
# 114078        26      42   70        13  1:15.493         75493     speed
# 114079        26      42   71        13  1:15.507         75507     speed
#
#          forename surname nationality  year  round  circuitId  \
# ...

# %%
f_one_df[f_one_df["date"] == (f_one_df[f_one_df["surname"]=="Vettel"]["date"].min())]["name"]
# Out:
# 112792    United States Grand Prix
# 112793    United States Grand Prix
# 112794    United States Grand Prix
# 112795    United States Grand Prix
# 112796    United States Grand Prix
#                     ...
# 114075    United States Grand Prix
# 114076    United States Grand Prix
# 114077    United States Grand Prix
# 114078    United States Grand Prix
# 114079    United States Grand Prix
# Name: name, Length: 1288, dtype: object

# %%
list(f_one_df[f_one_df["date"] == (f_one_df[f_one_df["surname"]=="Vettel"]["date"].min())]["name"])[1]
# Out:
# 'United States Grand Prix'
